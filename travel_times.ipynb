# %%
import geopandas as gp

# %%
hd = gp.read_file("inputs/Heidelberg.json")
hd.head()
# Out:
#                 id  index  pop_density  population  median_self0  \
# 0  891fae6db2fffff  12960          0.0         0.0     79.844660
# 1  891faad665bffff  12960          0.0         0.0     78.185897
# 2  891fae6db3bffff  12960          0.0         0.0     82.966887
# 3  891fae6db23ffff  12960          0.0         0.0     79.862928
# 4  891fae6db27ffff  12960          0.0         0.0     78.373457
#
#    median_self1  median_self2  median_self3  median_self4  median_self5  ...  \
# 0     79.844660     79.844660     84.230986     91.523636     84.553554  ...
# 1     78.185897     78.185897     82.000000     90.631673     84.086606  ...
# 2     82.966887     82.966887     89.078740     93.353873     85.725275  ...
# 3     79.862928     79.862928     85.173228     91.348199     82.137441  ...
# 4     78.373457     78.373457     83.265957     90.378007     81.841040  ...
#
#    median_self15  median_self16  median_self17  median_self18  median_self19  \
# 0      85.146602      85.063523      84.931507      83.861490      83.750813
# 1      84.706341      84.588065      84.587255      83.390295      83.265795
# 2      85.978346      86.243738      85.795635      85.104101      85.146262
# 3      82.217984      82.575045      81.583104      80.545184      80.530010
# 4      82.367065      82.465517      81.942326      80.486869      80.770021
#
#    median_self20  median_self21  median_self22  median_self23  \
# 0      90.694329      90.202381      89.346726      82.663717
# 1      89.934540      89.393333      88.533632      81.878873
# 2      92.283379      91.786280      91.513788      84.210191
# 3      89.441032      88.683957      88.464474      83.659517
# 4      89.018821      88.425610      88.081660      82.271277
#
#                                             geometry
# 0  POLYGON ((8.61057 49.36374, 8.61303 49.36314, ...
# 1  POLYGON ((8.61303 49.36314, 8.61527 49.36422, ...
# 2  POLYGON ((8.60317 49.36553, 8.60564 49.36493, ...
# 3  POLYGON ((8.60564 49.36493, 8.60787 49.36602, ...
# 4  POLYGON ((8.61258 49.36651, 8.61504 49.36591, ...
#
# [5 rows x 29 columns]

# %%
hd.explore(column='median_self17', cmap='magma_r')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7701f7244c1c14a8d1410143f37a8ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7701f7244c1c14a8d1410143f37a8ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7701f7244c1c14a8d1410143f37a8ca = L.map(
#                 &quot;map_c7701f7244c1c14a8d1410143f37a8ca&quot;,
#                 {
#                     center: [49.4058209535106, 8.683614307627042],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c7701f7244c1c14a8d1410143f37a8ca);
#
#
#
#
#
#             var tile_layer_5059b8c3473f36866450ba637ff2fdbe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5059b8c3473f36866450ba637ff2fdbe.addTo(map_c7701f7244c1c14a8d1410143f37a8ca);
#
#
#             map_c7701f7244c1c14a8d1410143f37a8ca.fitBounds(
#                 [[49.351103780973226, 8.571800573886499], [49.46053812604798, 8.795428041367584]],
#                 {}
#             );
#
#
#         function geo_json_1bba916e71fe19a0c4ae847c2c010f19_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;131&quot;: case &quot;133&quot;: case &quot;356&quot;: case &quot;438&quot;: case &quot;439&quot;: case &quot;442&quot;: case &quot;481&quot;: case &quot;532&quot;: case &quot;545&quot;: case &quot;550&quot;: case &quot;576&quot;: case &quot;811&quot;: case &quot;814&quot;: case &quot;843&quot;: case &quot;1154&quot;: case &quot;1164&quot;: case &quot;1197&quot;: case &quot;1206&quot;: case &quot;1219&quot;: case &quot;1243&quot;: case &quot;1258&quot;:
#                     return {&quot;color&quot;: &quot;#221150&quot;, &quot;fillColor&quot;: &quot;#221150&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;185&quot;: case &quot;352&quot;: case &quot;393&quot;: case &quot;434&quot;: case &quot;507&quot;: case &quot;850&quot;: case &quot;1170&quot;: case &quot;1236&quot;: case &quot;1240&quot;: case &quot;1259&quot;:
#                     return {&quot;color&quot;: &quot;#241253&quot;, &quot;fillColor&quot;: &quot;#241253&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;6&quot;: case &quot;9&quot;: case &quot;190&quot;: case &quot;368&quot;: case &quot;418&quot;: case &quot;536&quot;: case &quot;560&quot;: case &quot;565&quot;: case &quot;816&quot;: case &quot;818&quot;: case &quot;835&quot;: case &quot;1071&quot;: case &quot;1100&quot;: case &quot;1149&quot;: case &quot;1168&quot;: case &quot;1266&quot;: case &quot;1289&quot;:
#                     return {&quot;color&quot;: &quot;#20114b&quot;, &quot;fillColor&quot;: &quot;#20114b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;151&quot;: case &quot;433&quot;: case &quot;510&quot;: case &quot;537&quot;: case &quot;583&quot;: case &quot;587&quot;: case &quot;589&quot;: case &quot;734&quot;: case &quot;773&quot;: case &quot;776&quot;: case &quot;796&quot;: case &quot;828&quot;: case &quot;1055&quot;: case &quot;1092&quot;: case &quot;1125&quot;: case &quot;1146&quot;: case &quot;1212&quot;: case &quot;1229&quot;:
#                     return {&quot;color&quot;: &quot;#311165&quot;, &quot;fillColor&quot;: &quot;#311165&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;139&quot;: case &quot;141&quot;: case &quot;148&quot;: case &quot;152&quot;: case &quot;192&quot;: case &quot;316&quot;: case &quot;353&quot;: case &quot;359&quot;: case &quot;390&quot;: case &quot;394&quot;: case &quot;712&quot;: case &quot;714&quot;: case &quot;731&quot;: case &quot;770&quot;: case &quot;790&quot;: case &quot;794&quot;: case &quot;817&quot;: case &quot;819&quot;: case &quot;846&quot;: case &quot;859&quot;: case &quot;1126&quot;: case &quot;1148&quot;: case &quot;1208&quot;: case &quot;1210&quot;:
#                     return {&quot;color&quot;: &quot;#2f1163&quot;, &quot;fillColor&quot;: &quot;#2f1163&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;129&quot;: case &quot;389&quot

# %%
pivot = hd.loc[:, hd.columns.str.startswith("median")]
pivot["id"] = hd["id"]
plots = pivot.set_index("id").transpose().reset_index()
plots.plot(legend=False, xlabel="Time of Day [h]", ylabel="Mean Travel Time [min]")
# Out:
# /tmp/ipykernel_20414/3102864643.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivot["id"] = hd["id"]
# <Axes: xlabel='Time of Day [h]', ylabel='Mean Travel Time [min]'>

# %% [markdown]
# todo: group by districts
