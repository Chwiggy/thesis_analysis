# %%
import geopandas as gp

# %%
hd = gp.read_file("inputs/Heidelberg.json")
hd = hd.loc[hd.median_self17 != 0]
hd.head()
# Out:
#                 id  index  pop_density  population  median_self0  \
# 0  891fae6db2fffff  12960          0.0         0.0     79.844660
# 1  891faad665bffff  12960          0.0         0.0     78.185897
# 2  891fae6db3bffff  12960          0.0         0.0     82.966887
# 3  891fae6db23ffff  12960          0.0         0.0     79.862928
# 4  891fae6db27ffff  12960          0.0         0.0     78.373457
#
#    median_self1  median_self2  median_self3  median_self4  median_self5  ...  \
# 0     79.844660     79.844660     84.230986     91.523636     84.553554  ...
# 1     78.185897     78.185897     82.000000     90.631673     84.086606  ...
# 2     82.966887     82.966887     89.078740     93.353873     85.725275  ...
# 3     79.862928     79.862928     85.173228     91.348199     82.137441  ...
# 4     78.373457     78.373457     83.265957     90.378007     81.841040  ...
#
#    median_self15  median_self16  median_self17  median_self18  median_self19  \
# 0      85.146602      85.063523      84.931507      83.861490      83.750813
# 1      84.706341      84.588065      84.587255      83.390295      83.265795
# 2      85.978346      86.243738      85.795635      85.104101      85.146262
# 3      82.217984      82.575045      81.583104      80.545184      80.530010
# 4      82.367065      82.465517      81.942326      80.486869      80.770021
#
#    median_self20  median_self21  median_self22  median_self23  \
# 0      90.694329      90.202381      89.346726      82.663717
# 1      89.934540      89.393333      88.533632      81.878873
# 2      92.283379      91.786280      91.513788      84.210191
# 3      89.441032      88.683957      88.464474      83.659517
# 4      89.018821      88.425610      88.081660      82.271277
#
#                                             geometry
# 0  POLYGON ((8.61057 49.36374, 8.61303 49.36314, ...
# 1  POLYGON ((8.61303 49.36314, 8.61527 49.36422, ...
# 2  POLYGON ((8.60317 49.36553, 8.60564 49.36493, ...
# 3  POLYGON ((8.60564 49.36493, 8.60787 49.36602, ...
# 4  POLYGON ((8.61258 49.36651, 8.61504 49.36591, ...
#
# [5 rows x 29 columns]

# %%
hd.explore(column='median_self17', cmap='magma_r')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a159aca3eb0570288c8233f5d30a532 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a159aca3eb0570288c8233f5d30a532&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a159aca3eb0570288c8233f5d30a532 = L.map(
#                 &quot;map_5a159aca3eb0570288c8233f5d30a532&quot;,
#                 {
#                     center: [49.4058209535106, 8.683614307627042],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5a159aca3eb0570288c8233f5d30a532);
#
#
#
#
#
#             var tile_layer_53b5be04f75cd267404d5ba65722039e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_53b5be04f75cd267404d5ba65722039e.addTo(map_5a159aca3eb0570288c8233f5d30a532);
#
#
#             map_5a159aca3eb0570288c8233f5d30a532.fitBounds(
#                 [[49.351103780973226, 8.571800573886499], [49.46053812604798, 8.795428041367584]],
#                 {}
#             );
#
#
#         function geo_json_fd2c4c41f6a8550842bbe25f923d8de7_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;131&quot;: case &quot;133&quot;: case &quot;439&quot;: case &quot;442&quot;: case &quot;481&quot;: case &quot;576&quot;: case &quot;811&quot;: case &quot;814&quot;: case &quot;1206&quot;: case &quot;1219&quot;: case &quot;1243&quot;:
#                     return {&quot;color&quot;: &quot;#5a167e&quot;, &quot;fillColor&quot;: &quot;#5a167e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;352&quot;: case &quot;507&quot;: case &quot;1170&quot;: case &quot;1236&quot;: case &quot;1240&quot;: case &quot;1259&quot;:
#                     return {&quot;color&quot;: &quot;#5d177f&quot;, &quot;fillColor&quot;: &quot;#5d177f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;560&quot;: case &quot;816&quot;: case &quot;835&quot;: case &quot;1100&quot;: case &quot;1266&quot;:
#                     return {&quot;color&quot;: &quot;#54137d&quot;, &quot;fillColor&quot;: &quot;#54137d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;139&quot;: case &quot;353&quot;: case &quot;510&quot;: case &quot;537&quot;: case &quot;583&quot;: case &quot;589&quot;: case &quot;734&quot;: case &quot;770&quot;: case &quot;773&quot;: case &quot;776&quot;: case &quot;817&quot;: case &quot;1055&quot;: case &quot;1146&quot;:
#                     return {&quot;color&quot;: &quot;#752181&quot;, &quot;fillColor&quot;: &quot;#752181&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;141&quot;: case &quot;148&quot;: case &quot;152&quot;: case &quot;359&quot;: case &quot;390&quot;: case &quot;714&quot;: case &quot;853&quot;: case &quot;1148&quot;: case &quot;1208&quot;:
#                     return {&quot;color&quot;: &quot;#721f81&quot;, &quot;fillColor&quot;: &quot;#721f81&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;485&quot;: case &quot;1178&quot;:
#                     return {&quot;color&quot;: &quot;#471078&quot;, &quot;fillColor&quot;: &quot;#471078&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;9&quot;: case &quot;190&quot;: case &quot;368&quot;: case &quot;418&quot;: case &quot;536&quot;: case &quot;565&quot;: case &quot;818&quot;: case &quot;1071&quot;: case &quot;1289&quot;:
#                     return {&quot;color&quot;: &quot;#56147d&quot;, &quot;fillColor&quot;: &quot;#56147d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;61&quot;: case &quot;138&quot;: case &quot;178&quot;: case &quot;607&quot;: case &quot;609&quot;: case &quot;745&quot;: case &quot;765&quot;: case &quot;1064&quot;: case &quot;1119&quot;:
#                     return {&quot;color&quot;: &quot;#982d80&quot;, &quot;fillColor&quot;: &quot;#982d80&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;: case &quot;3

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use("ggplot")
ax = hd.plot(column = 'median_self17', cmap = 'magma_r', legend = True)
plt.title(label='Average Travel Times at 5 pm')
plt.xlabel(xlabel = '° E')
plt.ylabel(ylabel='° N')
# Out:
# Text(24.847222222222214, 0.5, '° N')

# %%
import matplotlib
matplotlib.style.use("ggplot")
pivot = hd.loc[:, hd.columns.str.startswith("median")]
pivot["id"] = hd["id"]
plots = pivot.set_index("id").transpose().reset_index()
plots.plot(legend=False, xlabel="Time of Day [h]", ylabel="Mean Travel Time [min]")
# Out:
# /tmp/ipykernel_11994/2465417434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivot["id"] = hd["id"]
# <Axes: xlabel='Time of Day [h]', ylabel='Mean Travel Time [min]'>

# %%
plots.head()
# Out:
# id         index  891fae6db2fffff  891faad665bffff  891fae6db3bffff  \
# 0   median_self0        79.844660        78.185897        82.966887
# 1   median_self1        79.844660        78.185897        82.966887
# 2   median_self2        79.844660        78.185897        82.966887
# 3   median_self3        84.230986        82.000000        89.078740
# 4   median_self4        91.523636        90.631673        93.353873
#
# id  891fae6db23ffff  891fae6db27ffff  891fae6db07ffff  891fae6db33ffff  \
# 0         79.862928        78.373457        84.808581        82.631579
# 1         79.862928        78.373457        84.808581        82.631579
# 2         79.862928        78.373457        84.808581        82.631579
# 3         85.173228        83.265957        91.735661        87.455801
# 4         91.348199        90.378007        94.247458        93.003650
#
# id  891fae6db37ffff  891faad66cbffff  ...  891faa986c3ffff  891faa980cbffff  \
# 0         79.226744        79.677326  ...        82.240122        81.446254
# 1         79.226744        79.677326  ...        82.240122        81.446254
# 2         79.226744        79.677326  ...        82.240122        81.446254
# 3         84.233251        83.410853  ...        82.811940        84.224551
# 4         90.558587        90.852564  ...        89.515679        90.939189
#
# id  891faa980dbffff  891faa986c7ffff  891faa98613ffff  891faa986d7ffff  \
# 0         82.618243        82.931464        81.766234        80.849850
# 1         82.618243        82.931464        81.766234        80.849850
# 2         82.618243        82.931464        81.766234        80.849850
# 3         84.858491        84.150150        83.914894        81.924419
# 4         89.743041        91.318072        85.493720        85.791960
#
# id  891faa9868bffff  891faa9868fffff  891faa9869bffff  891faa98683ffff
# 0         81.783699        79.715210        82.658065        85.162544
# 1         81.783699        79.715210        82.658065        85.162544
# 2         81.783699        79.715210        82.658065        85.162544
# 3         82.830816        81.314815        84.171254        86.928105
# 4         85.738308        83.561158        88.218182        89.667384
#
# [5 rows x 1301 columns]

# %% [markdown]
# todo: group by districts

# %%
boroughs = gp.read_file(filename="inputs/boroughs.json")
boroughs.head()
# Out:
#    bbox_north  bbox_south  bbox_east  bbox_west   place_id  osm_type   osm_id  \
# 0   49.415450   49.372224   8.768830   8.692388  139134533  relation  3283775
# 1   49.411332   49.396417   8.679977   8.641543  107771397  relation  3283776
# 2   49.412318   49.404317   8.694012   8.656512  107005928  relation  3283777
# 3   49.383825   49.366897   8.730404   8.700155  140246307  relation  3283778
# 4   49.371833   49.355110   8.728942   8.699760  139336012  relation  3283779
#
#          lat       lon     class            type  place_rank  importance  \
# 0  49.393824  8.721768  boundary  administrative          18     0.30001
# 1  49.404644  8.665469  boundary  administrative          18     0.30001
# 2  49.408113  8.678280  boundary  administrative          18     0.30001
# 3  49.375335  8.714003  boundary  administrative          18     0.30001
# 4  49.363661  8.713632  boundary  administrative          18     0.30001
#
#      addresstype          name  \
# 0  city_district      Altstadt
# 1  city_district     Bahnstadt
# 2  city_district      Bergheim
# 3  city_district       Boxberg
# 4  city_district  Emmertsgrund
#
#                                         display_name  \
# 0  Altstadt, Heidelberg, Baden-Württemberg, 69117...
# 1  Bahnstadt, Heidelberg, Baden-Württemberg, Germany
# 2   Bergheim, Heidelberg, Baden-Württemberg, Germany
# 3    Boxberg, Heidelberg, Baden-Württemberg, Germany
# 4  Emmertsgrund, Heidelberg, Baden-Württemberg, G...
#
#                                             geometry
# 0  POLYGON ((8.69239 49.41191, 8.69333 49.40964, ...
# 1  POLYGON ((8.64154 49.41130, 8.65239 49.40739, ...
# 2  POLYGON ((8.65651 49.41105, 8.65886 49.41022, ...
# 3  POLYGON ((8.70015 49.37283, 8.70030 49.37246, ...
# 4  POLYGON ((8.69976 49.36536, 8.69997 49.36319, ...

# %%
cells_by_borough = hd.sjoin(boroughs, how="left")
cells_by_borough.dropna(inplace=True)
cells_by_borough.head()
# Out:
#                 id  index  pop_density  population  median_self0  \
# 1  891faad665bffff  12960          0.0         0.0     78.185897
# 3  891fae6db23ffff  12960          0.0         0.0     79.862928
# 4  891fae6db27ffff  12960          0.0         0.0     78.373457
# 5  891fae6db07ffff  12960          0.0         0.0     84.808581
# 6  891fae6db33ffff  12960          0.0         0.0     82.631579
#
#    median_self1  median_self2  median_self3  median_self4  median_self5  ...  \
# 1     78.185897     78.185897     82.000000     90.631673     84.086606  ...
# 3     79.862928     79.862928     85.173228     91.348199     82.137441  ...
# 4     78.373457     78.373457     83.265957     90.378007     81.841040  ...
# 5     84.808581     84.808581     91.735661     94.247458     86.929221  ...
# 6     82.631579     82.631579     87.455801     93.003650     85.202783  ...
#
#       osm_id        lat       lon     class            type  place_rank  \
# 1  3283781.0  49.374638  8.640973  boundary  administrative        18.0
# 3  3283781.0  49.374638  8.640973  boundary  administrative        18.0
# 4  3283781.0  49.374638  8.640973  boundary  administrative        18.0
# 5  3283781.0  49.374638  8.640973  boundary  administrative        18.0
# 6  3283781.0  49.374638  8.640973  boundary  administrative        18.0
#
#    importance    addresstype       name  \
# 1     0.30001  city_district  Kirchheim
# 3     0.30001  city_district  Kirchheim
# 4     0.30001  city_district  Kirchheim
# 5     0.30001  city_district  Kirchheim
# 6     0.30001  city_district  Kirchheim
#
#                                         display_name
# 1  Kirchheim, Heidelberg, Baden-Württemberg, 6912...
# 3  Kirchheim, Heidelberg, Baden-Württemberg, 6912...
# 4  Kirchheim, Heidelberg, Baden-Württemberg, 6912...
# 5  Kirchheim, Heidelberg, Baden-Württemberg, 6912...
# 6  Kirchheim, Heidelberg, Baden-Württemberg, 6912...
#
# [5 rows x 46 columns]

# %%
pivot = hd.loc[:, hd.columns.str.startswith("median")]
pivot["id"] = hd["id"]
plots = pivot.set_index("id").transpose().reset_index()
plots.head()
# Out:
# /tmp/ipykernel_11994/4055111405.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivot["id"] = hd["id"]
# id         index  891fae6db2fffff  891faad665bffff  891fae6db3bffff  \
# 0   median_self0        79.844660        78.185897        82.966887
# 1   median_self1        79.844660        78.185897        82.966887
# 2   median_self2        79.844660        78.185897        82.966887
# 3   median_self3        84.230986        82.000000        89.078740
# 4   median_self4        91.523636        90.631673        93.353873
#
# id  891fae6db23ffff  891fae6db27ffff  891fae6db07ffff  891fae6db33ffff  \
# 0         79.862928        78.373457        84.808581        82.631579
# 1         79.862928        78.373457        84.808581        82.631579
# 2         79.862928        78.373457        84.808581        82.631579
# 3         85.173228        83.265957        91.735661        87.455801
# 4         91.348199        90.378007        94.247458        93.003650
#
# id  891fae6db37ffff  891faad66cbffff  ...  891faa986c3ffff  891faa980cbffff  \
# 0         79.226744        79.677326  ...        82.240122        81.446254
# 1         79.226744        79.677326  ...        82.240122        81.446254
# 2         79.226744        79.677326  ...        82.240122        81.446254
# 3         84.233251        83.410853  ...        82.811940        84.224551
# 4         90.558587        90.852564  ...        89.515679        90.939189
#
# id  891faa980dbffff  891faa986c7ffff  891faa98613ffff  891faa986d7ffff  \
# 0         82.618243        82.931464        81.766234        80.849850
# 1         82.618243        82.931464        81.766234        80.849850
# 2         82.618243        82.931464        81.766234        80.849850
# 3         84.858491        84.150150        83.914894        81.924419
# 4         89.743041        91.318072        85.493720        85.791960
#
# id  891faa9868bffff  891faa9868fffff  891faa9869bffff  891faa98683ffff
# 0         81.783699        79.715210        82.658065        85.162544
# 1         81.783699        79.715210        82.658065        85.162544
# 2         81.783699        79.715210        82.658065        85.162544
# 3         82.830816        81.314815        84.171254        86.928105
# 4         85.738308        83.561158        88.218182        89.667384
#
# [5 rows x 1301 columns]

# %%
mean_boroughs = cells_by_borough.groupby(["name"]).mean("median_self17")
mean_boroughs
# Out:
#                        index  pop_density  population  median_self0  \
# name
# Altstadt        11277.220930     3.143966    0.305357     77.887672
# Bahnstadt        6455.440000    22.833308    2.217136     78.057833
# Bergheim         5647.076923    26.780318    2.600522     78.283938
# Boxberg         12306.102564     3.183476    0.309393     75.598794
# Emmertsgrund    12573.348837     3.385829    0.329122     79.094997
# Handschuhsheim   7644.188482     6.473891    0.628407     81.056463
# Kirchheim       11181.822660     6.415162    0.623203     77.895756
# Neuenheim        6887.523256    15.390614    1.494310     80.247332
# Pfaffengrund     6806.245283    16.622043    1.613841     78.864154
# Rohrbach        11211.612903    17.049795    1.656752     77.431442
# Schlierbach     10358.222222     1.819464    0.176766     79.682348
# Südstadt         8925.241379    21.796477    2.117444     76.760222
# Weststadt        7384.517241    30.031249    2.916635     76.198859
# Wieblingen       7580.708108     4.155949    0.403341     80.021944
# Ziegelhausen     9974.480000     2.385237    0.231684     80.089974
#
#                 median_self1  median_self2  median_self3  median_self4  \
# name
# Altstadt           77.930564     77.978002     80.148389     78.686817
# Bahnstadt          78.335309     78.564862     78.592364     66.421304
# Bergheim           78.450469     78.510190     77.668791     64.805917
# Boxberg            75.598794     75.765770     80.868434     79.424077
# Emmertsgrund       79.094997     79.224947     84.480660     83.206180
# Handschuhsheim     80.992830     81.395417     85.276920     83.141644
# Kirchheim          78.088827     78.212038     82.332169     81.174588
# Neuenheim          80.332813     80.498523     81.598522     73.767608
# Pfaffengrund       78.996527     79.171905     80.096057     72.106381
# Rohrbach           77.820433     77.979672     82.168941     74.795433
# Schlierbach        79.728826     79.834119     82.411244     82.137517
# Südstadt           77.494319     77.494319     77.980761     67.768110
# Weststadt          77.516552     77.573704     77.210620     63.840583
# Wieblingen         78.148404     78.458537     86.262470     81.835090
# Ziegelhausen       80.095017     80.126356     81.984529     86.152990
#
#                 median_self5  median_self6  ...  bbox_north  bbox_south  \
# name                                        ...
# Altstadt           75.504071     72.574249  ...   49.415450   49.372224
# Bahnstadt          60.450086     57.231432  ...   49.411332   49.396417
# Bergheim           58.724716     55.852880  ...   49.412318   49.404317
# Boxberg            75.466647     71.996707  ...   49.383825   49.366897
# Emmertsgrund       77.415131     75.621841  ...   49.371833   49.355110
# Handschuhsheim     77.519905     76.057360  ...   49.452420   49.416655
# Kirchheim          75.511638     72.801213  ...   49.397620   49.352003
# Neuenheim          66.130872     64.203074  ...   49.429302   49.410229
# Pfaffengrund       66.678934     63.640209  ...   49.414928   49.390766
# Rohrbach           67.732836     66.168773  ...   49.389393   49.355716
# Schlierbach        73.986787     72.777652  ...   49.419108   49.386438
# Südstadt           60.688726     58.778826  ...   49.398786   49.383641
# Weststadt          57.683848     55.036392  ...   49.407422   49.394452
# Wieblingen         79.340825     77.755229  ...   49.443115   49.405467
# Ziegelhausen       79.938033     78.742436  ...   49.459693   49.401329
#
#                 bbox_east  bbox_west     place_id     osm_id        lat  \
# name
# Altstadt         8.768830   8.692388  139134533.0  3283775.0  49.393824
# Bahnstadt        8.679977   8.641543  107771397.0  3283776.0  49.404644
# Bergheim         8.694012   8.656512  107005928.0  3283777.0  49.408113
# Boxberg          8.730404   8.700155  140246307.0  3283778.0  49.375335
# Emmertsgrund     8.728942   8.699760  139336012.0  3283779.0  49.363661
# Handschuhsheim   8.740485   8.646552  108052811.0  3283780.0  49.433930
# Kirchheim        8.678009   8.601004  107954990.0  3283781.0  49.374638
# Neuenheim        8.733888   8.655573  139726050.0  3283782.0  49.419713
# Pfaffengrund     8.671368   8.633025  139407102.0  3283783.0  49.397685
# Rohrbach         8.715457   8.672443  139290330.0  3283784.0  49.372645
# Schlierbach      8.779198   8.717762  139368624.0  3283785.0  49.403033
# Südstadt         8.698881   8.676397  107453152.0  3283786.0  49.390884
# Weststadt        8.698847   8.670231  107682976.0  3283787.0  49.400945
# Wieblingen       8.662864   8.573179  108199268.0  3283788.0  49.424299
# Ziegelhausen     8.794050   8.725123  106765007.0  3283789.0  49.430607
#
#                      lon  place_rank  importance
# name
# Altstadt        8.721768        18.0    0.300010
# Bahnstadt       8.665469        18.0    0.300010
# Bergheim        8.678280        18.0    0.300010
# Boxberg         8.714003        18.0    0.300010
# Emmertsgrund    8.713632        18.0    0.300010
# Handschuhsheim  8.692343        18.0    0.300010
# Kirchheim       8.640973        18.0    0.300010
# Neuenheim       8.701755        18.0    0.300010
# Pfaffengrund    8.645710        18.0    0.267719
# Rohrbach        8.687259        18.0    0.300010
# Schlierbach     8.758121        18.0    0.300010
# Südstadt        8.686170        18.0    0.300010
# Weststadt       8.688524        18.0    0.300010
# Wieblingen      8.631398        18.0    0.300010
# Ziegelhausen    8.760083        18.0    0.300010
#
# [15 rows x 38 columns]

# %%
map = boroughs.merge(mean_boroughs, on="name", how = "inner", )
map.explore(column="median_self17", cmap="magma_r")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5fe54745b4550db98c9ffa2aa5831f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5fe54745b4550db98c9ffa2aa5831f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5fe54745b4550db98c9ffa2aa5831f2 = L.map(
#                 &quot;map_c5fe54745b4550db98c9ffa2aa5831f2&quot;,
#                 {
#                     center: [49.405847800000004, 8.683614200000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c5fe54745b4550db98c9ffa2aa5831f2);
#
#
#
#
#
#             var tile_layer_807cb344bf71bc1f803cbc963c404b5c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_807cb344bf71bc1f803cbc963c404b5c.addTo(map_c5fe54745b4550db98c9ffa2aa5831f2);
#
#
#             map_c5fe54745b4550db98c9ffa2aa5831f2.fitBounds(
#                 [[49.3520029, 8.5731788], [49.4596927, 8.7940496]],
#                 {}
#             );
#
#
#         function geo_json_936d4ee1e95fa0dca4bfc417ab7a39b0_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#4e117b&quot;, &quot;fillColor&quot;: &quot;#4e117b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fec88c&quot;, &quot;fillColor&quot;: &quot;#fec88c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#fde9aa&quot;, &quot;fillColor&quot;: &quot;#fde9aa&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#5f187f&quot;, &quot;fillColor&quot;: &quot;#5f187f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#1c1044&quot;, &quot;fillColor&quot;: &quot;#1c1044&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#271258&quot;, &quot;fillColor&quot;: &quot;#271258&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#420f75&quot;, &quot;fillColor&quot;: &quot;#420f75&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#e95462&quot;, &quot;fillColor&quot;: &quot;#e95462&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#e75263&quot;, &quot;fillColor&quot;: &quot;#e75263&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#4f127b&quot;, &quot;fillColor&quot;: &quot;#4f127b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#fec488&quot;, &quot;fillColor&quot;: &quot;#fec488&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#fcfdbf&quot;, &quot;fillColor&quot;: &quot;#fcfdbf&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#0b0924&quot;, &quot;fillColor&quot;: &quot;#0b0924&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;#000004&quot;, &quot;fillColor&quot;: &quot;#000004&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#d2426f&quot;, &quot;fillColor&quot;: &quot;#d2426f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_936d4ee1e95fa0dca4bfc417ab7a39b0_hig

# %%
import matplotlib
matplotlib.style.use("ggplot")
import matplotlib.pyplot as plt
ax = cells_by_borough.boxplot(column="median_self17", by= "name")
plt.xticks(rotation=90)
plt.title(label='Average Travel Times')
# Out:
# Text(0.5, 1.0, 'Average Travel Times')

# %%
cells_by_borough.boxplot("median_self17")
# Out:
# <Axes: >

# %%
pivot = mean_boroughs.loc[:, mean_boroughs.columns.str.startswith("median")]
pivot = pivot.rename(columns=lambda x: x.strip("median_self"))
pivot = pivot.transpose()
#pivot = pivot.transpose()
pivot.head()
# Out:
# name   Altstadt  Bahnstadt   Bergheim    Boxberg  Emmertsgrund  \
# 0     77.887672  78.057833  78.283938  75.598794     79.094997
# 1     77.930564  78.335309  78.450469  75.598794     79.094997
# 2     77.978002  78.564862  78.510190  75.765770     79.224947
# 3     80.148389  78.592364  77.668791  80.868434     84.480660
# 4     78.686817  66.421304  64.805917  79.424077     83.206180
#
# name  Handschuhsheim  Kirchheim  Neuenheim  Pfaffengrund   Rohrbach  \
# 0          81.056463  77.895756  80.247332     78.864154  77.431442
# 1          80.992830  78.088827  80.332813     78.996527  77.820433
# 2          81.395417  78.212038  80.498523     79.171905  77.979672
# 3          85.276920  82.332169  81.598522     80.096057  82.168941
# 4          83.141644  81.174588  73.767608     72.106381  74.795433
#
# name  Schlierbach   Südstadt  Weststadt  Wieblingen  Ziegelhausen
# 0       79.682348  76.760222  76.198859   80.021944     80.089974
# 1       79.728826  77.494319  77.516552   78.148404     80.095017
# 2       79.834119  77.494319  77.573704   78.458537     80.126356
# 3       82.411244  77.980761  77.210620   86.262470     81.984529
# 4       82.137517  67.768110  63.840583   81.835090     86.152990

# %%
ax = pivot.plot(legend = False)
plt.title(label='Average Travel Times from Cells per borough')
ax.legend(loc='center left', bbox_to_anchor = (1,0.5))
